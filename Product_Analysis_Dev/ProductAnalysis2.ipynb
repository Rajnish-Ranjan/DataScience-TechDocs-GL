# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from scipy.stats import zscore
plt.style.use('seaborn-whitegrid')
import requests
import csv
import datetime

# %%
url = "https://www.overleaf.com/project/63dbc4f5e94cb3bbc2645bca/updates?min_count=10"

# %%
from bs4 import BeautifulSoup

# %%
def readable_datetime(timestamp_ms):
    
    # Convert milliseconds to seconds by dividing by 1000
    timestamp_seconds = timestamp_ms / 1000

    # Convert to a datetime object
    date_time = datetime.datetime.fromtimestamp(timestamp_seconds)

    # Format the datetime object as a string
#     formatted_date_time = date_time.strftime("%Y-%m-%d %H:%M:%S")
    formatted_date = date_time.strftime("%Y-%m-%d")
    formatted_time = date_time.strftime("%H:%M:%S")
    return formatted_date

# %%
def timestamp_details(timestamp_ms):

    timestamp_seconds = timestamp_ms / 1000
    date_time = datetime.datetime.fromtimestamp(timestamp_seconds)

    # Extract individual components
    year = date_time.year
    month = date_time.month
    day = date_time.day
    hour = date_time.hour
    minute = date_time.minute
    second = date_time.second

    print("Year:", year)
    print("Month:", month)
    print("Day:", day)
    print("Hour:", hour)
    print("Minute:", minute)
    print("Second:", second)

# %%
data = '''{
    "updates": [
        {
            "fromV": 104,
            "toV": 109,
            "meta": {
                "users": [
                    {
                        "first_name": "amrut",
                        "last_name": "y",
                        "email": "amrut.y@gmail.com",
                        "id": "63dfe1d2b637820bf4f63dcb"
                    }
                ],
                "start_ts": 1681306779192,
                "end_ts": 1681307014887
            },
            "labels": [],
            "pathnames": [
                "deepDialogue.tex"
            ],
            "project_ops": []
        },
        {
            "fromV": 102,
            "toV": 104,
            "meta": {
                "users": [
                    {
                        "first_name": "amrut",
                        "last_name": "y",
                        "email": "amrut.y@gmail.com",
                        "id": "63dfe1d2b637820bf4f63dcb"
                    }
                ],
                "start_ts": 1681306516236,
                "end_ts": 1681306552774
            },
            "labels": [],
            "pathnames": [
                "deepDialogue.tex"
            ],
            "project_ops": []
        },
        {
            "fromV": 95,
            "toV": 102,
            "meta": {
                "users": [
                    {
                        "first_name": "amrut",
                        "last_name": "y",
                        "email": "amrut.y@gmail.com",
                        "id": "63dfe1d2b637820bf4f63dcb"
                    }
                ],
                "start_ts": 1681135165717,
                "end_ts": 1681135447559
            },
            "labels": [],
            "pathnames": [
                "deepDialogue.tex"
            ],
            "project_ops": []
        },
        {
            "fromV": 90,
            "toV": 95,
            "meta": {
                "users": [
                    {
                        "first_name": "amrut",
                        "last_name": "y",
                        "email": "amrut.y@gmail.com",
                        "id": "63dfe1d2b637820bf4f63dcb"
                    }
                ],
                "start_ts": 1681134862221,
                "end_ts": 1681135140818
            },
            "labels": [],
            "pathnames": [
                "deepDialogue.tex"
            ],
            "project_ops": []
        },
        {
            "fromV": 89,
            "toV": 90,
            "meta": {
                "users": [
                    {
                        "first_name": "amrut",
                        "last_name": "y",
                        "email": "amrut.y@gmail.com",
                        "id": "63dfe1d2b637820bf4f63dcb"
                    }
                ],
                "start_ts": 1681134803514,
                "end_ts": 1681134803514
            },
            "labels": [],
            "pathnames": [
                "deepDialogue.tex"
            ],
            "project_ops": []
        },
        {
            "fromV": 75,
            "toV": 89,
            "meta": {
                "users": [
                    {
                        "first_name": "subhajit",
                        "last_name": "chakraborty",
                        "email": "subhajit331992@gmail.com",
                        "id": "63e88ddac3b20eb09a187426"
                    }
                ],
                "start_ts": 1681060666741,
                "end_ts": 1681060916767
            },
            "labels": [],
            "pathnames": [
                "references.bib"
            ],
            "project_ops": []
        },
        {
            "fromV": 72,
            "toV": 75,
            "meta": {
                "users": [
                    {
                        "first_name": "subhajit",
                        "last_name": "chakraborty",
                        "email": "subhajit331992@gmail.com",
                        "id": "63e88ddac3b20eb09a187426"
                    }
                ],
                "start_ts": 1681060457377,
                "end_ts": 1681060554650
            },
            "labels": [],
            "pathnames": [
                "deepDialogue.tex"
            ],
            "project_ops": []
        },
        {
            "fromV": 63,
            "toV": 72,
            "meta": {
                "users": [
                    {
                        "first_name": "subhajit",
                        "last_name": "chakraborty",
                        "email": "subhajit331992@gmail.com",
                        "id": "63e88ddac3b20eb09a187426"
                    },
                    {
                        "first_name": "amrut",
                        "last_name": "y",
                        "email": "amrut.y@gmail.com",
                        "id": "63dfe1d2b637820bf4f63dcb"
                    }
                ],
                "start_ts": 1681059853464,
                "end_ts": 1681060117183
            },
            "labels": [],
            "pathnames": [
                "deepDialogue.tex"
            ],
            "project_ops": []
        },
        {
            "fromV": 60,
            "toV": 63,
            "meta": {
                "users": [
                    {
                        "first_name": "amrut",
                        "last_name": "y",
                        "email": "amrut.y@gmail.com",
                        "id": "63dfe1d2b637820bf4f63dcb"
                    }
                ],
                "start_ts": 1681058876781,
                "end_ts": 1681059013852
            },
            "labels": [],
            "pathnames": [
                "deepDialogue.tex"
            ],
            "project_ops": []
        },
        {
            "fromV": 59,
            "toV": 60,
            "meta": {
                "users": [
                    {
                        "first_name": "subhajit",
                        "last_name": "chakraborty",
                        "email": "subhajit331992@gmail.com",
                        "id": "63e88ddac3b20eb09a187426"
                    }
                ],
                "start_ts": 1681030527798,
                "end_ts": 1681030527798,
                "origin": {
                    "kind": "upload"
                }
            },
            "labels": [],
            "pathnames": [],
            "project_ops": [
                {
                    "add": {
                        "pathname": "References/Fitness_Group5_UpdatedPPT.pptx"
                    },
                    "atV": 59
                }
            ]
        },
        {
            "fromV": 58,
            "toV": 59,
            "meta": {
                "users": [
                    {
                        "first_name": "amrut",
                        "last_name": "y",
                        "email": "amrut.y@gmail.com",
                        "id": "63dfe1d2b637820bf4f63dcb"
                    }
                ],
                "start_ts": 1681023569867,
                "end_ts": 1681023569867
            },
            "labels": [],
            "pathnames": [
                "deepDialogue.tex"
            ],
            "project_ops": []
        },
        {
            "fromV": 56,
            "toV": 58,
            "meta": {
                "users": [
                    {
                        "first_name": "amrut",
                        "last_name": "y",
                        "email": "amrut.y@gmail.com",
                        "id": "63dfe1d2b637820bf4f63dcb"
                    }
                ],
                "start_ts": 1677434322152,
                "end_ts": 1677434324544
            },
            "labels": [],
            "pathnames": [],
            "project_ops": [
                {
                    "rename": {
                        "pathname": "Intro_Literature_Summary_Group5.edited.pdf",
                        "newPathname": "References/Intro_Literature_Summary_Group5.edited.pdf"
                    },
                    "atV": 57
                },
                {
                    "rename": {
                        "pathname": "Intro_Literature_Summary_Group5.edited.docx",
                        "newPathname": "References/Intro_Literature_Summary_Group5.edited.docx"
                    },
                    "atV": 56
                }
            ]
        },
        {
            "fromV": 54,
            "toV": 56,
            "meta": {
                "users": [
                    {
                        "first_name": "amrut",
                        "last_name": "y",
                        "email": "amrut.y@gmail.com",
                        "id": "63dfe1d2b637820bf4f63dcb"
                    }
                ],
                "start_ts": 1677434311586,
                "end_ts": 1677434312954,
                "origin": {
                    "kind": "upload"
                }
            },
            "labels": [],
            "pathnames": [],
            "project_ops": [
                {
                    "add": {
                        "pathname": "Intro_Literature_Summary_Group5.edited.pdf"
                    },
                    "atV": 55
                },
                {
                    "add": {
                        "pathname": "Intro_Literature_Summary_Group5.edited.docx"
                    },
                    "atV": 54
                }
            ]
        },
        {
            "fromV": 53,
            "toV": 54,
            "meta": {
                "users": [
                    {
                        "first_name": "amrut",
                        "last_name": "y",
                        "email": "amrut.y@gmail.com",
                        "id": "63dfe1d2b637820bf4f63dcb"
                    }
                ],
                "start_ts": 1677434289800,
                "end_ts": 1677434289800
            },
            "labels": [],
            "pathnames": [],
            "project_ops": [
                {
                    "remove": {
                        "pathname": "References/Capstone_Group5_Intro_Literature_Survey.pdf"
                    },
                    "atV": 53
                }
            ]
        },
        {
            "fromV": 52,
            "toV": 53,
            "meta": {
                "users": [
                    {
                        "first_name": "amrut",
                        "last_name": "y",
                        "email": "amrut.y@gmail.com",
                        "id": "63dfe1d2b637820bf4f63dcb"
                    }
                ],
                "start_ts": 1677432439316,
                "end_ts": 1677432439316
            },
            "labels": [],
            "pathnames": [],
            "project_ops": [
                {
                    "rename": {
                        "pathname": "Capstone_Group5_Intro_Literature_Survey.pdf",
                        "newPathname": "References/Capstone_Group5_Intro_Literature_Survey.pdf"
                    },
                    "atV": 52
                }
            ]
        },
        {
            "fromV": 51,
            "toV": 52,
            "meta": {
                "users": [
                    {
                        "first_name": "amrut",
                        "last_name": "y",
                        "email": "amrut.y@gmail.com",
                        "id": "63dfe1d2b637820bf4f63dcb"
                    }
                ],
                "start_ts": 1677432420861,
                "end_ts": 1677432420861,
                "origin": {
                    "kind": "upload"
                }
            },
            "labels": [],
            "pathnames": [],
            "project_ops": [
                {
                    "add": {
                        "pathname": "Capstone_Group5_Intro_Literature_Survey.pdf"
                    },
                    "atV": 51
                }
            ]
        },
        {
            "fromV": 50,
            "toV": 51,
            "meta": {
                "users": [
                    {
                        "first_name": "amrut",
                        "last_name": "y",
                        "email": "amrut.y@gmail.com",
                        "id": "63dfe1d2b637820bf4f63dcb"
                    }
                ],
                "start_ts": 1677432410708,
                "end_ts": 1677432410708
            },
            "labels": [],
            "pathnames": [],
            "project_ops": [
                {
                    "remove": {
                        "pathname": "References/Intro_Literature_Summary_Group5.docx"
                    },
                    "atV": 50
                }
            ]
        },
        {
            "fromV": 49,
            "toV": 50,
            "meta": {
                "users": [
                    {
                        "first_name": "amrut",
                        "last_name": "y",
                        "email": "amrut.y@gmail.com",
                        "id": "63dfe1d2b637820bf4f63dcb"
                    }
                ],
                "start_ts": 1677408930396,
                "end_ts": 1677408930396,
                "origin": {
                    "kind": "upload"
                }
            },
            "labels": [],
            "pathnames": [],
            "project_ops": [
                {
                    "add": {
                        "pathname": "References/Intro_Literature_Summary_Group5.docx"
                    },
                    "atV": 49
                }
            ]
        },
        {
            "fromV": 48,
            "toV": 49,
            "meta": {
                "users": [
                    {
                        "first_name": "subhajit",
                        "last_name": "chakraborty",
                        "email": "subhajit331992@gmail.com",
                        "id": "63e88ddac3b20eb09a187426"
                    }
                ],
                "start_ts": 1677403419523,
                "end_ts": 1677403419523,
                "origin": {
                    "kind": "upload"
                }
            },
            "labels": [],
            "pathnames": [],
            "project_ops": [
                {
                    "add": {
                        "pathname": "References/Literature Survey_Subhajit.docx"
                    },
                    "atV": 48
                }
            ]
        },
        {
            "fromV": 47,
            "toV": 48,
            "meta": {
                "users": [
                    {
                        "first_name": "subhajit",
                        "last_name": "chakraborty",
                        "email": "subhajit331992@gmail.com",
                        "id": "63e88ddac3b20eb09a187426"
                    }
                ],
                "start_ts": 1677403404752,
                "end_ts": 1677403404752
            },
            "labels": [],
            "pathnames": [],
            "project_ops": [
                {
                    "remove": {
                        "pathname": "References/Literature Survey_Subhajit.docx"
                    },
                    "atV": 47
                }
            ]
        },
        {
            "fromV": 46,
            "toV": 47,
            "meta": {
                "users": [
                    {
                        "first_name": "Ashok",
                        "last_name": "G",
                        "email": "gashok9909@gmail.com",
                        "id": "63e88e6b6a294dbaf7258c55"
                    }
                ],
                "start_ts": 1677397750136,
                "end_ts": 1677397750136,
                "origin": {
                    "kind": "upload"
                }
            },
            "labels": [],
            "pathnames": [],
            "project_ops": [
                {
                    "add": {
                        "pathname": "References/Ashok G_Literature_Survey.docx"
                    },
                    "atV": 46
                }
            ]
        },
        {
            "fromV": 45,
            "toV": 46,
            "meta": {
                "users": [
                    {
                        "first_name": "Ashok",
                        "last_name": "G",
                        "email": "gashok9909@gmail.com",
                        "id": "63e88e6b6a294dbaf7258c55"
                    }
                ],
                "start_ts": 1677397735376,
                "end_ts": 1677397735376
            },
            "labels": [],
            "pathnames": [],
            "project_ops": [
                {
                    "remove": {
                        "pathname": "Ashok G_Literature_Survey.docx"
                    },
                    "atV": 45
                }
            ]
        },
        {
            "fromV": 44,
            "toV": 45,
            "meta": {
                "users": [
                    {
                        "first_name": "Ashok",
                        "last_name": "G",
                        "email": "gashok9909@gmail.com",
                        "id": "63e88e6b6a294dbaf7258c55"
                    }
                ],
                "start_ts": 1677397725945,
                "end_ts": 1677397725945,
                "origin": {
                    "kind": "upload"
                }
            },
            "labels": [],
            "pathnames": [],
            "project_ops": [
                {
                    "add": {
                        "pathname": "Ashok G_Literature_Survey.docx"
                    },
                    "atV": 44
                }
            ]
        },
        {
            "fromV": 43,
            "toV": 44,
            "meta": {
                "users": [
                    {
                        "first_name": "santhanag55",
                        "last_name": "",
                        "email": "santhanag55@gmail.com",
                        "id": "63e77c44858bee11abe5cd01"
                    }
                ],
                "start_ts": 1677387347905,
                "end_ts": 1677387347905,
                "origin": {
                    "kind": "upload"
                }
            },
            "labels": [],
            "pathnames": [],
            "project_ops": [
                {
                    "add": {
                        "pathname": "References/Santhana_Literature_Survey.docx"
                    },
                    "atV": 43
                }
            ]
        },
        {
            "fromV": 42,
            "toV": 43,
            "meta": {
                "users": [
                    {
                        "first_name": "santhanag55",
                        "last_name": "",
                        "email": "santhanag55@gmail.com",
                        "id": "63e77c44858bee11abe5cd01"
                    }
                ],
                "start_ts": 1677387331716,
                "end_ts": 1677387331716
            },
            "labels": [],
            "pathnames": [],
            "project_ops": [
                {
                    "remove": {
                        "pathname": "References/Santhana_Literature_survey.txt"
                    },
                    "atV": 42
                }
            ]
        },
        {
            "fromV": 41,
            "toV": 42,
            "meta": {
                "users": [
                    {
                        "first_name": "subhajit",
                        "last_name": "chakraborty",
                        "email": "subhajit331992@gmail.com",
                        "id": "63e88ddac3b20eb09a187426"
                    }
                ],
                "start_ts": 1677332420109,
                "end_ts": 1677332420109,
                "origin": {
                    "kind": "upload"
                }
            },
            "labels": [],
            "pathnames": [],
            "project_ops": [
                {
                    "add": {
                        "pathname": "References/Literature Survey_Subhajit.docx"
                    },
                    "atV": 41
                }
            ]
        },
        {
            "fromV": 39,
            "toV": 41,
            "meta": {
                "users": [
                    {
                        "first_name": "Vandhitha",
                        "last_name": "P",
                        "email": "pvandhi69@gmail.com",
                        "id": "63dc925c24a755ff871f8c01"
                    }
                ],
                "start_ts": 1677256052477,
                "end_ts": 1677256052905,
                "origin": {
                    "kind": "upload"
                }
            },
            "labels": [],
            "pathnames": [],
            "project_ops": [
                {
                    "add": {
                        "pathname": "References/Citations - Vandhitha P.xlsx"
                    },
                    "atV": 40
                },
                {
                    "add": {
                        "pathname": "References/Literature survey - Vandhitha P.docx"
                    },
                    "atV": 39
                }
            ]
        },
        {
            "fromV": 37,
            "toV": 39,
            "meta": {
                "users": [
                    {
                        "first_name": "Vandhitha",
                        "last_name": "P",
                        "email": "pvandhi69@gmail.com",
                        "id": "63dc925c24a755ff871f8c01"
                    }
                ],
                "start_ts": 1677255996423,
                "end_ts": 1677256004200
            },
            "labels": [],
            "pathnames": [],
            "project_ops": [
                {
                    "remove": {
                        "pathname": "Literature survey - Vandhitha P.docx"
                    },
                    "atV": 38
                },
                {
                    "remove": {
                        "pathname": "Citations - Vandhitha P.xlsx"
                    },
                    "atV": 37
                }
            ]
        },
        {
            "fromV": 36,
            "toV": 37,
            "meta": {
                "users": [
                    {
                        "first_name": "santhanag55",
                        "last_name": "",
                        "email": "santhanag55@gmail.com",
                        "id": "63e77c44858bee11abe5cd01"
                    }
                ],
                "start_ts": 1677254100979,
                "end_ts": 1677254100979,
                "origin": {
                    "kind": "upload"
                }
            },
            "labels": [],
            "pathnames": [],
            "project_ops": [
                {
                    "add": {
                        "pathname": "References/Santhana_Literature_survey.txt"
                    },
                    "atV": 36
                }
            ]
        },
        {
            "fromV": 34,
            "toV": 36,
            "meta": {
                "users": [
                    {
                        "first_name": "Vandhitha",
                        "last_name": "P",
                        "email": "pvandhi69@gmail.com",
                        "id": "63dc925c24a755ff871f8c01"
                    }
                ],
                "start_ts": 1677248546319,
                "end_ts": 1677248546791,
                "origin": {
                    "kind": "upload"
                }
            },
            "labels": [],
            "pathnames": [],
            "project_ops": [
                {
                    "add": {
                        "pathname": "Citations - Vandhitha P.xlsx"
                    },
                    "atV": 35
                },
                {
                    "add": {
                        "pathname": "Literature survey - Vandhitha P.docx"
                    },
                    "atV": 34
                }
            ]
        },
        {
            "fromV": 32,
            "toV": 34,
            "meta": {
                "users": [
                    {
                        "first_name": "Vandhitha",
                        "last_name": "P",
                        "email": "pvandhi69@gmail.com",
                        "id": "63dc925c24a755ff871f8c01"
                    }
                ],
                "start_ts": 1677248504264,
                "end_ts": 1677248510916
            },
            "labels": [],
            "pathnames": [],
            "project_ops": [
                {
                    "remove": {
                        "pathname": "Citations.xlsx"
                    },
                    "atV": 33
                },
                {
                    "remove": {
                        "pathname": "Literature survey.docx"
                    },
                    "atV": 32
                }
            ]
        },
        {
            "fromV": 30,
            "toV": 32,
            "meta": {
                "users": [
                    {
                        "first_name": "Vandhitha",
                        "last_name": "P",
                        "email": "pvandhi69@gmail.com",
                        "id": "63dc925c24a755ff871f8c01"
                    }
                ],
                "start_ts": 1677248491222,
                "end_ts": 1677248491778,
                "origin": {
                    "kind": "upload"
                }
            },
            "labels": [],
            "pathnames": [],
            "project_ops": [
                {
                    "add": {
                        "pathname": "Citations.xlsx"
                    },
                    "atV": 31
                },
                {
                    "add": {
                        "pathname": "Literature survey.docx"
                    },
                    "atV": 30
                }
            ]
        },
        {
            "fromV": 25,
            "toV": 30,
            "meta": {
                "users": [
                    {
                        "first_name": "Narayana",
                        "last_name": "Darapaneni",
                        "email": "narayana@greatlearning.in",
                        "id": "5e2d78e8954fe50001947c16"
                    }
                ],
                "start_ts": 1676357209544,
                "end_ts": 1676357355551
            },
            "labels": [],
            "pathnames": [
                "deepDialogue.tex"
            ],
            "project_ops": []
        },
        {
            "fromV": 24,
            "toV": 25,
            "meta": {
                "users": [
                    {
                        "first_name": "vishnuvardhan031.m",
                        "last_name": "",
                        "email": "vishnuvardhan031.m@gmail.com",
                        "id": "63dbc6cb9c4ea257a05b9fc5"
                    }
                ],
                "start_ts": 1676200608260,
                "end_ts": 1676200608260,
                "origin": {
                    "kind": "upload"
                }
            },
            "labels": [],
            "pathnames": [],
            "project_ops": [
                {
                    "add": {
                        "pathname": "References/097_Vishnu_M_Capstone Project__.docx"
                    },
                    "atV": 24
                }
            ]
        },
        {
            "fromV": 23,
            "toV": 24,
            "meta": {
                "users": [
                    {
                        "first_name": "amrut",
                        "last_name": "y",
                        "email": "amrut.y@gmail.com",
                        "id": "63dfe1d2b637820bf4f63dcb"
                    }
                ],
                "start_ts": 1676200487574,
                "end_ts": 1676200487574
            },
            "labels": [],
            "pathnames": [],
            "project_ops": [
                {
                    "rename": {
                        "pathname": "Litrature_Summary_10Research_Amrut.docx",
                        "newPathname": "References/Litrature_Summary_10Research_Amrut.docx"
                    },
                    "atV": 23
                }
            ]
        },
        {
            "fromV": 22,
            "toV": 23,
            "meta": {
                "users": [
                    {
                        "first_name": "amrut",
                        "last_name": "y",
                        "email": "amrut.y@gmail.com",
                        "id": "63dfe1d2b637820bf4f63dcb"
                    }
                ],
                "start_ts": 1676200465790,
                "end_ts": 1676200465790,
                "origin": {
                    "kind": "upload"
                }
            },
            "labels": [],
            "pathnames": [],
            "project_ops": [
                {
                    "add": {
                        "pathname": "Litrature_Summary_10Research_Amrut.docx"
                    },
                    "atV": 22
                }
            ]
        },
        {
            "fromV": 20,
            "toV": 22,
            "meta": {
                "users": [
                    {
                        "first_name": "Vandhitha",
                        "last_name": "P",
                        "email": "pvandhi69@gmail.com",
                        "id": "63dc925c24a755ff871f8c01"
                    }
                ],
                "start_ts": 1676108152697,
                "end_ts": 1676108169038
            },
            "labels": [],
            "pathnames": [
                "deepDialogue.tex"
            ],
            "project_ops": []
        },
        {
            "fromV": 18,
            "toV": 20,
            "meta": {
                "users": [
                    {
                        "first_name": "Narayana",
                        "last_name": "Darapaneni",
                        "email": "narayana@greatlearning.in",
                        "id": "5e2d78e8954fe50001947c16"
                    }
                ],
                "start_ts": 1675347211543,
                "end_ts": 1675347211543
            },
            "labels": [],
            "pathnames": [
                "deepDialogue.tex"
            ],
            "project_ops": []
        },
        {
            "fromV": 0,
            "toV": 18,
            "meta": {
                "users": [
                    {
                        "first_name": "Narayana",
                        "last_name": "Darapaneni",
                        "email": "narayana@greatlearning.in",
                        "id": "5e2d78e8954fe50001947c16"
                    }
                ],
                "start_ts": 1675347189528,
                "end_ts": 1675347189539
            },
            "labels": [],
            "pathnames": [],
            "project_ops": [
                {
                    "add": {
                        "pathname": "images/Picture1.png"
                    },
                    "atV": 17
                },
                {
                    "add": {
                        "pathname": "images/result5.png"
                    },
                    "atV": 16
                },
                {
                    "add": {
                        "pathname": "images/result4.png"
                    },
                    "atV": 15
                },
                {
                    "add": {
                        "pathname": "images/result3.png"
                    },
                    "atV": 14
                },
                {
                    "add": {
                        "pathname": "images/result2.png"
                    },
                    "atV": 13
                },
                {
                    "add": {
                        "pathname": "images/result1.png"
                    },
                    "atV": 12
                },
                {
                    "add": {
                        "pathname": "images/unet-model-Page-2.png"
                    },
                    "atV": 11
                },
                {
                    "add": {
                        "pathname": "images/train-test-patient-distrubution.png"
                    },
                    "atV": 10
                },
                {
                    "add": {
                        "pathname": "images/test-mask-distribution.png"
                    },
                    "atV": 9
                },
                {
                    "add": {
                        "pathname": "images/tain-mask-distribution.png"
                    },
                    "atV": 8
                },
                {
                    "add": {
                        "pathname": "images/l-parotid-dsc.png"
                    },
                    "atV": 7
                },
                {
                    "add": {
                        "pathname": "images/spinal-cord-dsc.png"
                    },
                    "atV": 6
                },
                {
                    "add": {
                        "pathname": "images/multi-organ-dsc.png"
                    },
                    "atV": 5
                },
                {
                    "add": {
                        "pathname": "images/no-of-slices.png"
                    },
                    "atV": 4
                },
                {
                    "add": {
                        "pathname": "images/r-parotid-dsc.png"
                    },
                    "atV": 3
                },
                {
                    "add": {
                        "pathname": "deepDialogue.tex"
                    },
                    "atV": 2
                },
                {
                    "add": {
                        "pathname": "references.bib"
                    },
                    "atV": 1
                },
                {
                    "add": {
                        "pathname": "arxiv.sty"
                    },
                    "atV": 0
                }
            ]
        }
    ]
}'''

# %%
import json

data_json = f'''{data}'''

# Parse the JSON data
parsed_data = json.loads(data_json)
# print(parsed_data)

# Access and print specific elements from the parsed data
updates = parsed_data['updates']
for update in updates:
    fromV = update['fromV']
    toV = update['toV']
    meta = update['meta']
    users = meta['users']
    start_ts = meta['start_ts']
    end_ts = meta['end_ts']
    pathnames = update['pathnames']
    project_ops = update['project_ops']

    print("fromV:", fromV)
    print("toV:", toV)
    print("users:", users)
    print("start_ts:", readable_datetime(start_ts))
    print("end_ts:", readable_datetime(end_ts))
    print("pathnames:", pathnames)
    print("project_ops:", project_ops)
# Out:
# fromV: 104
# toV: 109
# users: [{'first_name': 'amrut', 'last_name': 'y', 'email': 'amrut.y@gmail.com', 'id': '63dfe1d2b637820bf4f63dcb'}]
# start_ts: 2023-04-12
# end_ts: 2023-04-12
# pathnames: ['deepDialogue.tex']
# project_ops: []
# fromV: 102
# toV: 104
# users: [{'first_name': 'amrut', 'last_name': 'y', 'email': 'amrut.y@gmail.com', 'id': '63dfe1d2b637820bf4f63dcb'}]
# start_ts: 2023-04-12
# end_ts: 2023-04-12
# pathnames: ['deepDialogue.tex']
# project_ops: []
# fromV: 95
# toV: 102
# users: [{'first_name': 'amrut', 'last_name': 'y', 'email': 'amrut.y@gmail.com', 'id': '63dfe1d2b637820bf4f63dcb'}]
# start_ts: 2023-04-10
# end_ts: 2023-04-10
# pathnames: ['deepDialogue.tex']
# project_ops: []
# fromV: 90
# toV: 95
# users: [{'first_name': 'amrut', 'last_name': 'y', 'email': 'amrut.y@gmail.com', 'id': '63dfe1d2b637820bf4f63dcb'}]
# start_ts: 2023-04-10
# end_ts: 2023-04-10
# pathnames: ['deepDialogue.tex']
# project_ops: []
# fromV: 89
# toV: 90
# ...

# %%
data_json = f'''{data}'''

# Parse the JSON data
parsed_data = json.loads(data_json)

# Create an empty list to store the extracted data
extracted_data = []

# Extract specific pieces of information
updates = parsed_data["updates"]
for update in updates:
    from_version = update["fromV"]
    to_version = update["toV"]
    users = update["meta"]["users"]
    start_timestamp = update["meta"]["start_ts"]
    end_timestamp = update["meta"]["end_ts"]
    labels = update["labels"]
    pathnames = update["pathnames"]
    project_ops = update["project_ops"]
    
    extracted_data.append({
        "from_version": from_version,
        "to_version": to_version,
        "users": users,
        "start_timestamp": start_timestamp,
        "end_timestamp": end_timestamp,
        "Labels": labels,
        "Pathnames": pathnames,
        "project_ops": project_ops
    })

# Create a Pandas DataFrame from the list of dictionaries
original_df = pd.DataFrame(extracted_data)

# Print the DataFrame
original_df.head(50)

    # Print the extracted information
#     print("From Version:", from_version)
#     print("To Version:", to_version)
#     print("Users:", users)
#     print("Start Timestamp:", readable_datetime(start_timestamp))
#     print("End Timestamp:", readable_datetime(end_timestamp))
#     print("Pathnames:", pathnames)
#     print("Project Operations:", project_ops)
# Out:
#     from_version  to_version  \
# 0            104         109
# 1            102         104
# 2             95         102
# 3             90          95
# 4             89          90
# 5             75          89
# 6             72          75
# 7             63          72
# 8             60          63
# 9             59          60
# 10            58          59
# 11            56          58
# 12            54          56
# 13            53          54
# 14            52          53
# 15            51          52
# 16            50          51
# 17            49          50
# 18            48          49
# 19            47          48
# 20            46          47
# 21            45          46
# 22            44          45
# 23            43          44
# 24            42          43
# 25            41          42
# 26            39          41
# 27            37          39
# 28            36          37
# 29            34          36
# 30            32          34
# ...

# %%
data_json = f'''{data}'''

# Parse the JSON data
parsed_data = json.loads(data_json)

# Create an empty list to store the extracted data
extracted_data = []

# Extract specific pieces of information
updates = parsed_data["updates"]
for update in updates:
    from_version = update["fromV"]
    to_version = update["toV"]
    users = update["meta"]["users"]
    start_timestamp = update["meta"]["start_ts"]
    end_timestamp = update["meta"]["end_ts"]
    labels = update["labels"]
    pathnames = update["pathnames"]
    project_ops = update["project_ops"]
    
    extracted_data.append({
        "from_version": from_version,
        "to_version": to_version,
        "user_f_name": users[0]['first_name'],
        "user_l_name": users[0]['last_name'],
        "email_id": users[0]['email'],
        "user_id": users[0]['id'],
        "start_timestamp": readable_datetime(start_timestamp),
        "end_timestamp": readable_datetime(end_timestamp),
        "Labels": labels,
        "Pathnames": pathnames,
        "project_ops": project_ops
    })

# Create a Pandas DataFrame from the list of dictionaries
stats_df = pd.DataFrame(extracted_data)

# Print the DataFrame
stats_df.head(50)

    # Print the extracted information
#     print("From Version:", from_version)
#     print("To Version:", to_version)
#     print("Users:", users)
#     print("Start Timestamp:", readable_datetime(start_timestamp))
#     print("End Timestamp:", readable_datetime(end_timestamp))
#     print("Pathnames:", pathnames)
#     print("Project Operations:", project_ops)
# Out:
#     from_version  to_version         user_f_name  user_l_name  \
# 0            104         109               amrut            y
# 1            102         104               amrut            y
# 2             95         102               amrut            y
# 3             90          95               amrut            y
# 4             89          90               amrut            y
# 5             75          89            subhajit  chakraborty
# 6             72          75            subhajit  chakraborty
# 7             63          72            subhajit  chakraborty
# 8             60          63               amrut            y
# 9             59          60            subhajit  chakraborty
# 10            58          59               amrut            y
# 11            56          58               amrut            y
# 12            54          56               amrut            y
# 13            53          54               amrut            y
# ...

# %%
stats_df['user_f_name'].nunique()
# Out:
# 7

# %%
stats_df['user_id'].nunique()
# Out:
# 7

# %%
stats_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   from_version     39 non-null     int64
#  1   to_version       39 non-null     int64
#  2   user_f_name      39 non-null     object
#  3   user_l_name      39 non-null     object
#  4   email_id         39 non-null     object
#  5   user_id          39 non-null     object
#  6   start_timestamp  39 non-null     object
#  7   end_timestamp    39 non-null     object
#  8   Labels           39 non-null     object
#  9   Pathnames        39 non-null     object
#  10  project_ops      39 non-null     object
# dtypes: int64(2), object(9)
# memory usage: 3.5+ KB

# %%
stats_df[['user_f_name']].groupby('user_f_name',as_index=False).value_counts()
# Out:
#           user_f_name  count
# 0               Ashok      3
# 1            Narayana      3
# 2           Vandhitha      6
# 3               amrut     16
# 4         santhanag55      3
# 5            subhajit      7
# 6  vishnuvardhan031.m      1

# %%
# Number of commits by user
commit_frequency=stats_df[['user_f_name']]
commit_frequency = commit_frequency.groupby('user_f_name',as_index=False).value_counts()
commit_frequency= commit_frequency.sort_values('count',ascending=False)
plt.figure(figsize=(13,6))
x=commit_frequency['user_f_name']
y=commit_frequency['count']

plt.bar(x,y, color = 'g', width = 0.75)
plt.xticks( rotation=90)

plt.title("Number of commits by user", fontsize=16)
plt.xlabel("User Name", fontsize=18)
plt.ylabel("Number of Commits", fontsize=18)
plt.show()

# %%
# Number of commits by Date
commit_frequency=stats_df[['end_timestamp']]
commit_frequency = commit_frequency.groupby('end_timestamp',as_index=False).value_counts()
commit_frequency= commit_frequency.sort_values('count',ascending=False)
plt.figure(figsize=(13,6))
x=commit_frequency['end_timestamp']
y=commit_frequency['count']

plt.bar(x,y, color = 'g', width = 0.75)
plt.xticks( rotation=90)

plt.title("Number of commits by Date", fontsize=16)
plt.xlabel("Date", fontsize=18)
plt.ylabel("Number of Commits", fontsize=18)
plt.show()

# %%
edit_ops = stats_df["Pathnames"][stats_df['Pathnames'].apply(lambda x: len(x) == 1)].count()

# %%
file_ops = stats_df["project_ops"][stats_df['project_ops'].apply(lambda x: len(x) >= 1)].count()

# %%
stats_df['Pathnames'].apply(lambda x: 'deepDialogue.tex' in x)
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5     False
# 6      True
# 7      True
# 8      True
# 9     False
# 10     True
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32     True
# 33    False
# 34    False
# 35    False
# 36     True
# 37     True
# 38    False
# Name: Pathnames, dtype: bool

# %%
# Nature and Frequency of Operations
labels = ['Edit Operations', 'File Operations']
ops_list = [edit_ops, file_ops]

# Create the Bar Plot
plt.bar(labels, ops_list, color='grey', edgecolor='yellow')
plt.xlabel('Operations')
plt.ylabel('Frequency')
plt.title('Nature and Frequency of Operations')
plt.show()

# %%
# stats_df['Pathnames'] = stats_df['Pathnames'].astype(str)

# %%
file_dict = {}  # Create an empty dictionary
for file_list in stats_df['Pathnames']:
    for file_name in file_list:
        if file_name in file_dict:
            file_dict[file_name] += 1
        else:
            file_dict[file_name] = 1

# Append or add an item if it doesn't exist
print(file_dict)
# Out:
# {'deepDialogue.tex': 12, 'references.bib': 1}

# %%
# Nature and Frequency of Operations
labels = file_dict.keys()
ops_list = file_dict.values()

# Create the Bar Plot
plt.bar(labels, ops_list, color='grey', edgecolor='yellow')
plt.xlabel('Files')
plt.ylabel('Frequency')
plt.title('No of Operations by file')
plt.show()
